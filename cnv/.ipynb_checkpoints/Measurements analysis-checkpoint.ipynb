# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Load measurements data

# %%
measurements = pd.read_excel("Metrics.xlsx").round(3)
measurements
# Out:
#       Puzzle  Area  Missing ele  % miss elements  Miss parameter Strategy  \
# 0     9x9_01    81           22            0.272              81      DLX
# 1     9x9_01    81           22            0.272              81      BFS
# 2     9x9_01    81           22            0.272              81       CP
# 3     9x9_01    81           16            0.198              54      DLX
# 4     9x9_01    81           16            0.198              54      BFS
# ..       ...   ...          ...              ...             ...      ...
# 58  25X25_01   625           80            0.128             416      BFS
# 59  25X25_01   625           80            0.128             416       CP
# 60  25X25_01   625           46            0.074             208      DLX
# 61  25X25_01   625           46            0.074             208      BFS
# 62  25X25_01   625           46            0.074             208       CP
#
#     Instructions  Methods  avg inst/method       Cost      Blocks  Field load  \
# 0      552853702     3580           154428   3580.000   234811035      319990
# 1      279987748      943           296911   1199.123   119984751        2741
# 2      242926882      766           317136    974.049   104102209        3187
# 3      540760952     3566           151643   3566.000   229545840      319810
# 4      199699392      806           247766    965.210    85578086        1979
# ..           ...      ...              ...        ...         ...         ...
# 58    2565392079     6832           375497   7706.496  1099319297       43260
# 59    2462313855     5741           428900   6475.848  1055156220       52135
# 60    5237684629    36532           143373  36532.000  1869326215    43124906
# 61    1605919279     5289           303634   5678.270   688172843       23564
# 62    1297087560     4585           282898   4922.456   555823249       29039
#
#     Field store  Regular load  Regular store   new  newarray  anew array  \
# 0         10520      81579233       78483275  1038        60           5
# 1            23      40021575       39989362    38         0           4
# 2            23      34720826       34696712   156         0           4
# 3         10426      79930773       76749802  1030        66           5
# 4            23      28545477       28521926    38         0           4
# ..          ...           ...            ...   ...       ...         ...
# 58           23     366786265      366370389    54         0           4
# 59           23     351977002      351668968  1250         0           4
# 60        79252    1197934506      668213063  7598       580           5
# 61           23     229593634      229349622    54         0           4
# 62           23     185424274      185245263   684         0           4
#
#     multianewarray  Execution Time (unistrumented)
# 0                2                        5648.850
# 1                1                        2893.327
# 2                1                        2558.782
# 3                2                        5586.226
# 4                1                        2150.788
# ..             ...                             ...
# 58               1                       26436.883
# 59               1                       25370.664
# 60               2                       41046.163
# 61               1                       16546.461
# 62               1                       13487.676
#
# [63 rows x 20 columns]

# %%
measurements.describe()
# Out:
#              Area  Missing ele  % miss elements  Miss parameter  Instructions  \
# count   63.000000    63.000000        63.000000       63.000000  6.300000e+01
# mean   233.714286    34.714286         0.165238      155.619048  1.185503e+09
# std    180.547325    25.620952         0.062187      144.910921  1.294410e+09
# min     81.000000     9.000000         0.070000       27.000000  8.647419e+07
# 25%     81.000000    16.000000         0.110000       54.000000  3.335265e+08
# 50%    256.000000    23.000000         0.150000       85.000000  5.528558e+08
# 75%    256.000000    46.000000         0.210000      208.000000  1.766310e+09
# max    625.000000   114.000000         0.270000      625.000000  5.315604e+09
#
#             Methods  avg inst/method          Cost        Blocks  \
# count     63.000000        63.000000     63.000000  6.300000e+01
# mean    5687.333333    256382.873016   5942.005873  4.847469e+08
# std     8042.946962    123356.369371   8000.804236  4.990882e+08
# min      602.000000    138393.000000    668.890000  3.705598e+07
# 25%      977.000000    148478.000000   1204.910000  1.429250e+08
# 50%     3305.000000    212395.000000   3547.000000  2.348113e+08
# 75%     5563.000000    336252.000000   6498.375000  7.282412e+08
# max    36784.000000    633912.000000  36784.000000  1.922791e+09
#
#          Field load   Field store  Regular load  Regular store          new  \
# count  6.300000e+01     63.000000  6.300000e+01   6.300000e+01    63.000000
# mean   2.810690e+06  10116.539683  1.975014e+08   1.642588e+08  1147.015873
# std    9.245836e+06  19656.512295  2.629058e+08   1.725898e+08  1829.266215
# min    1.072000e+03     23.000000  1.236173e+07   1.234991e+07    38.000000
# 25%    3.396000e+03     23.000000  4.767568e+07   4.763452e+07    45.000000
# 50%    1.838000e+04     23.000000  8.157998e+07   7.848343e+07   223.000000
# 75%    3.199010e+05  10473.000000  3.006902e+08   2.451725e+08  1058.000000
# max    4.312915e+07  81414.000000  1.197935e+09   6.807657e+08  7782.000000
#
#          newarray  anew array  multianewarray  Execution Time (unistrumented)
# count   63.000000   63.000000       63.000000                       63.000000
# mean    66.666667    4.333333        1.333333                    11542.627302
# std    132.408337    0.475191        0.475191                    11491.002898
# min      0.000000    4.000000        1.000000                      919.180000
# 25%      0.000000    4.000000        1.000000                     3533.070000
# 50%      0.000000    4.000000        1.000000                     5800.410000
# 75%     66.000000    5.000000        2.000000                    17394.035000
# max    580.000000    5.000000        2.000000                    42739.730000

# %% [markdown]
# ## Notes:
# The metrics: __multianewarray, anew array, miss parameter__ seem to be useless.

# %%
measurements = measurements.drop(['multianewarray','anew array','Miss parameter'], axis=1)

# %% [markdown]
# # 3. Correlation Matrix

# %%
corr_features = measurements.copy()
corr_features.drop(['Puzzle','Strategy'], axis=1)
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr_features.corr(), annot=True, linewidths=.9, fmt= '.2f',ax=ax)

# %% [markdown]
# ## Notes
#
# __1)__ Number of __instructions__ is __highly correlated with number of blocks (0.99)__. Thus, __we will not comment on number of blocks__. Furthemore, __instructions__ has a __correlation of 0.86 with methods__. Moreover, __methods__ has __rather less overhead than instructions or blocks__, since these 3 have a __high correlation among them__, it would be __benefic performance wise to keep only methods__.
#
# __2)__ __Area__ is __highly correlated__ with __regular load (0.75)__ and __regular store (0.83)__. Also, it has a __high correlation__ with __instructions (0.82)__.
#
# ---
#
# ### Hypothesis 1:
# The __high correlation of Area__ with __regular load__ and __regular store__ may indicate that __as these values increase, bigger chunks of memory are being allocated__. We will verify if this is true of false in __section 4__.
#
# This conclusion __would be useful since our metrics do not give us the amount of memory allocated__.
#
# ---
#
# __3) Missing elements__ are __highly correlated__ with __instructions (0.84)__. Thefore, the more incomplete the puzzles are, the more __computationally demanding is to solve it__. Also, it is also __highly correlated__ with __regular store (0.86)__. Furthermore, the correlation with __regular load__ is __(0.78)__. This will be __analyzed in further detail in section 4__.

# %% [markdown]
# # 4. Mean values grouped on missing elements and strategy

# %%
sec41 = measurements.groupby(['Area','Missing ele','Strategy'], as_index=True)['Instructions','Methods','avg inst/method','% miss elements',
                                                                               'Cost'].mean().round(3)

methods_ratio, instructions_ratio, cost_ratio = getRatios2(sec41['Methods'], sec41['Instructions'],sec41['Cost'])
sec41.insert(1,"Instructions increase", instructions_ratio)
sec41.insert(3,"Methods increase", methods_ratio)
sec41.insert(5,"Cost increase",cost_ratio)

sec41
# Out:
#                            Instructions  Instructions increase    Methods  \
# Area Missing ele Strategy
# 81   9           BFS       1.098048e+08                    NaN    643.667
#                  CP        9.745401e+07                    NaN    625.667
#                  DLX       5.266531e+08                    NaN   3548.333
#      16          BFS       2.250880e+08                  2.050    848.000
#                  CP        1.942078e+08                  1.993    722.000
#                  DLX       5.407618e+08                  1.027   3572.667
#      22          BFS       3.136109e+08                  1.393    999.667
#                  CP        2.889014e+08                  1.488    818.667
#                  DLX       5.528554e+08                  1.022   3593.333
# 256  23          BFS       3.994247e+08                    NaN   1851.667
#                  CP        3.884431e+08                    NaN   1810.667
#                  DLX       1.766309e+09                    NaN  12755.000
#      39          BFS       7.720594e+08                  1.933   2469.000
#                  CP        1.035542e+09                  2.666   2505.333
#                  DLX       1.795406e+09                  1.016  12839.000
#      54          BFS       1.881017e+09                  2.436   4254.667
#                  CP        1.617449e+09                  1.562   3085.333
#                  DLX       1.822690e+09                  1.015  12932.667
# 625  46          BFS       1.605919e+09                    NaN   5289.000
#                  CP        1.297088e+09                    NaN   4585.000
#                  DLX       5.237685e+09                    NaN  36532.000
#      80          BFS       2.565392e+09                  1.597   6832.000
#                  CP        2.462314e+09                  1.898   5741.000
#                  DLX       5.276632e+09                  1.007  36642.000
#      114         BFS       3.868759e+09                  1.508   8910.000
#                  CP        4.074284e+09                  1.655   7361.000
#                  DLX       5.315604e+09                  1.007  36784.000
#
#                            Methods increase  avg inst/method  Cost increase  \
# Area Missing ele Strategy
# 81   9           BFS                    NaN       168643.000            NaN
#                  CP                     NaN       155560.333            NaN
#                  DLX                    NaN       148422.333            NaN
#      16          BFS                  1.317       259273.333          1.505
#                  CP                   1.154       265422.667          1.318
#                  DLX                  1.007       151362.000          1.007
#      22          BFS                  1.179       310468.000          1.304
#                  CP                   1.134       350913.333          1.254
#                  DLX                  1.006       153857.000          1.006
# 256  23          BFS                    NaN       214600.333            NaN
#                  CP                     NaN       214029.333            NaN
#                  DLX                    NaN       138480.000            NaN
#      39          BFS                  1.333       310756.000          1.474
#                  CP                   1.384       392333.000          1.529
#                  DLX                  1.007       139840.333          1.007
#      54          BFS                  1.723       435771.333          1.879
#                  CP                   1.232       496532.333          1.343
#                  DLX                  1.007       140937.000          1.007
# 625  46          BFS                    NaN       303634.000            NaN
#                  CP                     NaN       282898.000            NaN
#                  DLX                    NaN       143373.000            NaN
#      80          BFS                  1.292       375497.000          1.413
#                  CP                   1.252       428900.000          1.370
#                  DLX                  1.003       144005.000          1.003
#      114         BFS                  1.304       434204.000          1.416
#                  CP                   1.282       553496.000          1.392
#                  DLX                  1.004       144509.000          1.004
#
#                            % miss elements       Cost
# Area Missing ele Strategy
# 81   9           BFS                 0.111   1573.121
#                  CP                  0.111   1758.499
#                  DLX                 0.111   3548.333
#      16          BFS                 0.198   2367.616
#                  CP                  0.198   2318.198
#                  DLX                 0.198   3572.667
#      22          BFS                 0.272   3086.971
#                  CP                  0.272   2907.249
#                  DLX                 0.272   3593.333
# 256  23          BFS                 0.090   4369.933
#                  CP                  0.090   4914.149
#                  DLX                 0.090  12755.000
#      39          BFS                 0.152   6439.152
#                  CP                  0.152   7513.996
#                  DLX                 0.152  12839.000
#      54          BFS                 0.211  12100.272
#                  CP                  0.211  10090.891
#                  DLX                 0.211  12932.667
# 625  46          BFS                 0.074  12143.544
#                  CP                  0.074  12106.234
#                  DLX                 0.074  36532.000
#      80          BFS                 0.128  17161.984
#                  CP                  0.128  16584.601
#                  DLX                 0.128  36642.000
#      114         BFS                 0.182  24306.480
#                  CP                  0.182  23092.929
#                  DLX                 0.182  36784.000

# %%
sec42 = measurements.groupby(['% miss elements','Strategy'], as_index=True)['Area','Missing ele','Instructions','Methods','Cost','avg inst/method','Blocks',
                                                 'Field load','Field store', 'Regular load','Regular store',
                                                'new', 'newarray'].mean().round(0)
a,b = sec42.iloc[[15,16,17]], sec42.iloc[[18,19,20]]

temp = sec42.iloc[[15,16,17]].copy()
sec42.iloc[[15,16,17]] = b.values
sec42.iloc[[18,19,20]] = temp.values

methods_ratio, instructions_ratio, cost_ratio = getRatios1(sec42['Methods'], sec42['Instructions'],sec42['Cost'])
sec42.insert(3,"Instructions increase", instructions_ratio)
sec42.insert(5,"Methods increase", methods_ratio)
sec42.insert(7,"Cost increase", cost_ratio)

sec42
# Out:
#                            Area  Missing ele  Instructions  \
# % miss elements Strategy
# 0.074           BFS       625.0         46.0  1.605919e+09
#                 CP        625.0         46.0  1.297088e+09
#                 DLX       625.0         46.0  5.237685e+09
# 0.090           BFS       256.0         23.0  3.994247e+08
#                 CP        256.0         23.0  3.884431e+08
#                 DLX       256.0         23.0  1.766309e+09
# 0.111           BFS        81.0          9.0  1.098048e+08
#                 CP         81.0          9.0  9.745401e+07
#                 DLX        81.0          9.0  5.266531e+08
# 0.128           BFS       625.0         80.0  2.565392e+09
#                 CP        625.0         80.0  2.462314e+09
#                 DLX       625.0         80.0  5.276632e+09
# 0.152           BFS       256.0         39.0  7.720594e+08
#                 CP        256.0         39.0  1.035542e+09
#                 DLX       256.0         39.0  1.795406e+09
# 0.182           BFS        81.0         16.0  2.250880e+08
#                 CP         81.0         16.0  1.942078e+08
#                 DLX        81.0         16.0  5.407618e+08
# 0.198           BFS       625.0        114.0  3.868759e+09
#                 CP        625.0        114.0  4.074284e+09
#                 DLX       625.0        114.0  5.315604e+09
# 0.211           BFS       256.0         54.0  1.881017e+09
#                 CP        256.0         54.0  1.617449e+09
#                 DLX       256.0         54.0  1.822690e+09
# 0.272           BFS        81.0         22.0  3.136109e+08
#                 CP         81.0         22.0  2.889014e+08
#                 DLX        81.0         22.0  5.528554e+08
#
#                           Instructions increase  Methods  Methods increase  \
# % miss elements Strategy
# 0.074           BFS                        4.02   5289.0              2.86
#                 CP                         3.34   4585.0              2.53
#                 DLX                        2.97  36532.0              2.86
# 0.090           BFS                        3.64   1852.0              2.88
#                 CP                         3.99   1811.0              2.89
#                 DLX                        3.35  12755.0              3.59
# 0.111           BFS                         NaN    644.0               NaN
#                 CP                          NaN    626.0               NaN
#                 DLX                         NaN   3548.0               NaN
# 0.128           BFS                        3.32   6832.0              2.77
#                 CP                         2.38   5741.0              2.29
#                 DLX                        2.94  36642.0              2.85
# 0.152           BFS                        3.43   2469.0              2.91
#                 CP                         5.33   2505.0              3.47
#                 DLX                        3.32  12839.0              3.59
# 0.182           BFS                         NaN    848.0               NaN
#                 CP                          NaN    722.0               NaN
#                 DLX                         NaN   3573.0               NaN
# 0.198           BFS                        2.06   8910.0              2.09
#                 CP                         2.52   7361.0              2.39
#                 DLX                        2.92  36784.0              2.84
# 0.211           BFS                        6.00   4255.0              4.26
#                 CP                         5.60   3085.0              3.77
#                 DLX                        3.30  12933.0              3.60
# 0.272           BFS                         NaN   1000.0               NaN
#                 CP                          NaN    819.0               NaN
#                 DLX                         NaN   3593.0               NaN
#
#                              Cost  Cost increase  avg inst/method  \
# % miss elements Strategy
# 0.074           BFS       12144.0           2.78         303634.0
#                 CP        12106.0           2.46         282898.0
#                 DLX       36532.0           2.86         143373.0
# 0.090           BFS        4370.0           2.78         214600.0
#                 CP         4914.0           2.80         214029.0
#                 DLX       12755.0           3.59         138480.0
# 0.111           BFS        1573.0            NaN         168643.0
#                 CP         1758.0            NaN         155560.0
#                 DLX        3548.0            NaN         148422.0
# 0.128           BFS       17162.0           2.67         375497.0
#                 CP        16585.0           2.21         428900.0
#                 DLX       36642.0           2.85         144005.0
# 0.152           BFS        6439.0           2.72         310756.0
#                 CP         7514.0           3.24         392333.0
#                 DLX       12839.0           3.59         139840.0
# 0.182           BFS        2368.0            NaN         259273.0
#                 CP         2318.0            NaN         265423.0
#                 DLX        3573.0            NaN         151362.0
# 0.198           BFS       24306.0           2.01         434204.0
#                 CP        23093.0           2.29         553496.0
#                 DLX       36784.0           2.84         144509.0
# 0.211           BFS       12100.0           3.92         435771.0
#                 CP        10091.0           3.47         496532.0
#                 DLX       12933.0           3.60         140937.0
# 0.272           BFS        3087.0            NaN         310468.0
#                 CP         2907.0            NaN         350913.0
#                 DLX        3593.0            NaN         153857.0
#
#                                 Blocks  Field load  Field store  Regular load  \
# % miss elements Strategy
# 0.074           BFS       6.881728e+08     23564.0         23.0  2.295936e+08
#                 CP        5.558232e+08     29039.0         23.0  1.854243e+08
#                 DLX       1.869326e+09  43124906.0      79252.0  1.197935e+09
# 0.090           BFS       1.711632e+08      5294.0         23.0  5.710279e+07
#                 CP        1.664547e+08      7488.0         23.0  5.552846e+07
#                 DLX       7.166887e+08   4909363.0      32617.0  3.006900e+08
# 0.111           BFS       4.705465e+07      1211.0         23.0  1.569654e+07
#                 CP        4.176096e+07      1598.0         23.0  1.393076e+07
#                 DLX       2.234033e+08    319569.0      10301.0  7.800786e+07
# 0.128           BFS       1.099319e+09     43260.0         23.0  3.667863e+08
#                 CP        1.055156e+09     52135.0         23.0  3.519770e+08
#                 DLX       1.896055e+09  43126658.0      80145.0  1.193974e+09
# 0.152           BFS       3.308487e+08     10014.0         23.0  1.103715e+08
#                 CP        4.437596e+08     17231.0         23.0  1.480149e+08
#                 DLX       7.303962e+08   4910935.0      33416.0  3.036668e+08
# 0.182           BFS       9.645837e+07      2086.0         23.0  3.217381e+07
#                 CP        8.322387e+07      2715.0         23.0  2.775835e+07
#                 DLX       2.295460e+08    319963.0      10504.0  7.993108e+07
# 0.198           BFS       1.657821e+09     74036.0         23.0  5.531679e+08
#                 CP        1.745931e+09     84744.0         23.0  5.823873e+08
#                 DLX       1.922791e+09  43129146.0      81414.0  1.190030e+09
# 0.211           BFS       8.060759e+08     22309.0         23.0  2.688902e+08
#                 CP        6.931280e+08     25960.0         23.0  2.311835e+08
#                 DLX       7.432485e+08   4912773.0      34340.0  3.064605e+08
# 0.272           BFS       1.343939e+08      2911.0         23.0  4.482686e+07
#                 CP        1.238043e+08      3615.0         23.0  4.129109e+07
#                 DLX       2.348113e+08    320297.0      10677.0  8.157986e+07
#
#                           Regular store     new  newarray
# % miss elements Strategy
# 0.074           BFS         229349622.0    54.0       0.0
#                 CP          185245263.0   684.0       0.0
#                 DLX         668213063.0  7598.0     580.0
# 0.090           BFS          57043908.0    45.0       0.0
#                 CP           55476070.0   234.0       0.0
#                 DLX         243647776.0  3149.0     234.0
# 0.111           BFS          15682315.0    38.0       0.0
#                 CP           13918208.0    85.0       0.0
#                 DLX          74727400.0  1019.0      73.0
# 0.128           BFS         366370389.0    54.0       0.0
#                 CP          351668968.0  1250.0       0.0
#                 DLX         674489216.0  7674.0     546.0
# 0.152           BFS         110264456.0    45.0       0.0
#                 CP          147901181.0   548.0       0.0
#                 DLX         247893341.0  3217.0     218.0
# 0.182           BFS          32148369.0    38.0       0.0
#                 CP           27737885.0   132.0       0.0
#                 DLX          76749867.0  1037.0      66.0
# 0.198           BFS         552495283.0    54.0       0.0
#                 CP          581898322.0  2033.0       0.0
#                 DLX         680765699.0  7782.0     512.0
# 0.211           BFS         268651690.0    45.0       0.0
#                 CP          231015122.0   831.0       0.0
#                 DLX         251873715.0  3296.0     203.0
# 0.272           BFS          44791957.0    38.0       0.0
#                 CP           41263518.0   178.0       0.0
#                 DLX          78483404.0  1051.0      60.0

# %%
measurements.groupby(['Strategy','Area','% miss elements'], as_index=True)['Instructions','Methods','avg inst/method','Missing ele','Blocks',
                                                 'Field load','Field store', 'Regular load','Regular store',
                                                'new', 'newarray'].mean().round(0)
# Out:
#                                Instructions  Methods  avg inst/method  \
# Strategy Area % miss elements
# BFS      81   0.11             1.098048e+08    644.0         168643.0
#               0.20             2.250880e+08    848.0         259273.0
#               0.27             3.136109e+08   1000.0         310468.0
#          256  0.09             3.994247e+08   1852.0         214600.0
#               0.15             7.720594e+08   2469.0         310756.0
#               0.21             1.881017e+09   4255.0         435771.0
#          625  0.07             1.605919e+09   5289.0         303634.0
#               0.13             2.565392e+09   6832.0         375497.0
#               0.18             3.868759e+09   8910.0         434204.0
# CP       81   0.11             9.745401e+07    626.0         155560.0
#               0.20             1.942078e+08    722.0         265423.0
#               0.27             2.889014e+08    819.0         350913.0
#          256  0.09             3.884431e+08   1811.0         214029.0
#               0.15             1.035542e+09   2505.0         392333.0
#               0.21             1.617449e+09   3085.0         496532.0
#          625  0.07             1.297088e+09   4585.0         282898.0
#               0.13             2.462314e+09   5741.0         428900.0
#               0.18             4.074284e+09   7361.0         553496.0
# DLX      81   0.11             5.266531e+08   3548.0         148422.0
#               0.20             5.407618e+08   3573.0         151362.0
#               0.27             5.528554e+08   3593.0         153857.0
#          256  0.09             1.766309e+09  12755.0         138480.0
#               0.15             1.795406e+09  12839.0         139840.0
#               0.21             1.822690e+09  12933.0         140937.0
#          625  0.07             5.237685e+09  36532.0         143373.0
#               0.13             5.276632e+09  36642.0         144005.0
#               0.18             5.315604e+09  36784.0         144509.0
#
#                                Missing ele        Blocks  Field load  \
# Strategy Area % miss elements
# BFS      81   0.11                     9.0  4.705465e+07      1211.0
#               0.20                    16.0  9.645837e+07      2086.0
#               0.27                    22.0  1.343939e+08      2911.0
#          256  0.09                    23.0  1.711632e+08      5294.0
#               0.15                    39.0  3.308487e+08     10014.0
#               0.21                    54.0  8.060759e+08     22309.0
#          625  0.07                    46.0  6.881728e+08     23564.0
#               0.13                    80.0  1.099319e+09     43260.0
#               0.18                   114.0  1.657821e+09     74036.0
# CP       81   0.11                     9.0  4.176096e+07      1598.0
#               0.20                    16.0  8.322387e+07      2715.0
#               0.27                    22.0  1.238043e+08      3615.0
#          256  0.09                    23.0  1.664547e+08      7488.0
#               0.15                    39.0  4.437596e+08     17231.0
#               0.21                    54.0  6.931280e+08     25960.0
#          625  0.07                    46.0  5.558232e+08     29039.0
#               0.13                    80.0  1.055156e+09     52135.0
#               0.18                   114.0  1.745931e+09     84744.0
# DLX      81   0.11                     9.0  2.234033e+08    319569.0
#               0.20                    16.0  2.295460e+08    319963.0
#               0.27                    22.0  2.348113e+08    320297.0
#          256  0.09                    23.0  7.166887e+08   4909363.0
#               0.15                    39.0  7.303962e+08   4910935.0
#               0.21                    54.0  7.432485e+08   4912773.0
#          625  0.07                    46.0  1.869326e+09  43124906.0
#               0.13                    80.0  1.896055e+09  43126658.0
#               0.18                   114.0  1.922791e+09  43129146.0
#
#                                Field store  Regular load  Regular store  \
# Strategy Area % miss elements
# BFS      81   0.11                    23.0  1.569654e+07     15682315.0
#               0.20                    23.0  3.217381e+07     32148369.0
#               0.27                    23.0  4.482686e+07     44791957.0
#          256  0.09                    23.0  5.710279e+07     57043908.0
#               0.15                    23.0  1.103715e+08    110264456.0
#               0.21                    23.0  2.688902e+08    268651690.0
#          625  0.07                    23.0  2.295936e+08    229349622.0
#               0.13                    23.0  3.667863e+08    366370389.0
#               0.18                    23.0  5.531679e+08    552495283.0
# CP       81   0.11                    23.0  1.393076e+07     13918208.0
#               0.20                    23.0  2.775835e+07     27737885.0
#               0.27                    23.0  4.129109e+07     41263518.0
#          256  0.09                    23.0  5.552846e+07     55476070.0
#               0.15                    23.0  1.480149e+08    147901181.0
#               0.21                    23.0  2.311835e+08    231015122.0
#          625  0.07                    23.0  1.854243e+08    185245263.0
#               0.13                    23.0  3.519770e+08    351668968.0
#               0.18                    23.0  5.823873e+08    581898322.0
# DLX      81   0.11                 10301.0  7.800786e+07     74727400.0
#               0.20                 10504.0  7.993108e+07     76749867.0
#               0.27                 10677.0  8.157986e+07     78483404.0
#          256  0.09                 32617.0  3.006900e+08    243647776.0
#               0.15                 33416.0  3.036668e+08    247893341.0
#               0.21                 34340.0  3.064605e+08    251873715.0
#          625  0.07                 79252.0  1.197935e+09    668213063.0
#               0.13                 80145.0  1.193974e+09    674489216.0
#               0.18                 81414.0  1.190030e+09    680765699.0
#
#                                   new  newarray
# Strategy Area % miss elements
# BFS      81   0.11               38.0       0.0
#               0.20               38.0       0.0
#               0.27               38.0       0.0
#          256  0.09               45.0       0.0
#               0.15               45.0       0.0
#               0.21               45.0       0.0
#          625  0.07               54.0       0.0
#               0.13               54.0       0.0
#               0.18               54.0       0.0
# CP       81   0.11               85.0       0.0
#               0.20              132.0       0.0
#               0.27              178.0       0.0
#          256  0.09              234.0       0.0
#               0.15              548.0       0.0
#               0.21              831.0       0.0
#          625  0.07              684.0       0.0
#               0.13             1250.0       0.0
#               0.18             2033.0       0.0
# DLX      81   0.11             1019.0      73.0
#               0.20             1037.0      66.0
#               0.27             1051.0      60.0
#          256  0.09             3149.0     234.0
#               0.15             3217.0     218.0
#               0.21             3296.0     203.0
#          625  0.07             7598.0     580.0
#               0.13             7674.0     546.0
#               0.18             7782.0     512.0

# %%
measurements.groupby(['Strategy'], as_index=True)['Instructions','Methods','avg inst/method','Missing ele','Blocks',
                                                 'Field load','Field store', 'Regular load','Regular store',
                                                'new', 'newarray'].mean().round(0)
# Out:
#           Instructions  Methods  avg inst/method  Missing ele       Blocks  \
# Strategy
# BFS       9.115755e+08   2582.0         295803.0         35.0  390633166.0
# CP        8.904608e+08   2209.0         328079.0         35.0  381585916.0
# DLX       1.754474e+09  12271.0         145266.0         35.0  682021629.0
#
#           Field load  Field store  Regular load  Regular store     new  \
# Strategy
# BFS          12968.0         23.0   130320615.0    130188732.0    43.0
# CP           16273.0         23.0   127281424.0    127178500.0   476.0
# DLX        8402829.0      30304.0   334902255.0    235409261.0  2922.0
#
#           newarray
# Strategy
# BFS            0.0
# CP             0.0
# DLX          200.0

# %% [markdown]
# ## Notes:
#
# Recall that (9,16,22) belong to the 9x9 puzzle, (23,39,54) to the 16x16 and (46,80,114) to the 25x25.
#
# Instructions decreased from missing element 46->54 while having also increased the size of the puzzle from 16x16->25x25. __It is necessary to take into consideration the new feature: % of missing elements of the puzzle__.
#
# __1)__ __Increasing missing elements__ has a __high impact in instructions for the CP__ and __BFS__ algorithm (__doubling missing elements__ almost __doubles instructions__). Furthermore, remember that it had a __correlation of  0.89 between this two features__. However, it does not influence __instructions for DLX__.
#
#
# __2.1) Increasing missing elements__ leads to an __increase of methods for the CP__ and __BFS__, specially in the __16x16__ puzzle. However, __since it does not influence DLX that much and this solver has higher values in methods__ it makes sense that __the correlation is only 0.58__.

# %% [markdown]
# __2.2)__ Now we have a __correlation__ of __0.96 between methods and instructions__.
#
# __3)__ __Increasing missing elements had a correlation of 0.91 with regular store and 0.78 with regular load__. By analyzing each __strategy__ we observe that this happens __mostly__ for the __CP__ and __BFS__. In fact, __varying missing elements did not have an impact in regular load and store for DLX__.
#
# ---
# ### Hypothesis 1:
# We made a hypothesis in __section 3__ that __bigger allocations__ may be __associated__ with __regular store and load__. To conclude if this is __true__ we will need to __conclude__ if the __increase in regular store and load__ were __more__ due to __an increase of missing elements__ or __bigger chunks of memory were allocated__.
#
# ---

# %%
hyp1_measurements = pd.read_excel("MetricsHyp1_1.xlsx")
hyp1_measurements
# Out:
#      Puzzle  Area  Mising ele Strategy  Field load  Field store  Regular load  \
# 0    9x9_01    81          22      DLX      319990        10520      81579233
# 1    9x9_01    81          22      BFS        2741           23      40021575
# 2    9x9_01    81          22       CP        3187           23      34720826
# 3  16x16_02   256          22      DLX     4909364        32617     300504192
# 4  16x16_02   256          22      BFS        5556           23      64751901
# 5  16x16_02   256          22       CP        7721           23      60039154
# 6  16x16_02   256          54      DLX     4913308        34591     306461554
# 7  16x16_02   256          54      BFS       28626           23     368740452
# 8  16x16_02   256          54       CP       42453           23     392224358
#
#    Regular store
# 0       78483275
# 1       39989362
# 2       34696712
# 3      243382467
# 4       64688790
# 5       59984586
# 6      251873954
# 7      368427705
# 8      391950513

# %% [markdown]
# ### Hypothesis 1 conclusion:
#
# As we __increased__ the __Area__ of the puzzle, the __regular load and store increased__ for __CP__ and __BFS__. However, comparing with the tests of __increasing both Area and missing elements__, __regular load and store increased by a more significative amount for these__. Thus, our hypothesis is __false for CP__ and __BFS__ but is __true__ for __DLX__.

# %%
hyp2_measurements = pd.read_excel("MetricsHyp1_2.xlsx")
hyp2_measurements

# %% [markdown]
# ### Hypothesis 1 conclusion
# Our hypothesis being __false for CP and BFS__ is even more __clear__ with these tests, as the __regular load and store__ actually __decreased__.
#
# Finnaly, __with the given metrics__, we __cannot be sure__ about the __amount of memory allocated for CP and BFS__.

# %% [markdown]
# # 5. Mean values grouped on Puzzle area and Strategy

# %%
measurements.groupby(['Area','Missing ele','Strategy'], as_index=True)['Instructions','Blocks','Methods',
                                                 'Field load','Field store','avg inst/method', 'Regular load','Regular store',
                                                'new', 'newarray'].mean().round(0)
# Out:
#                            Instructions        Blocks  Methods  Field load  \
# Area Missing ele Strategy
# 81   9           BFS       1.098048e+08  4.705465e+07    644.0      1211.0
#                  CP        9.745401e+07  4.176096e+07    626.0      1598.0
#                  DLX       5.266531e+08  2.234033e+08   3548.0    319569.0
#      16          BFS       2.250880e+08  9.645837e+07    848.0      2086.0
#                  CP        1.942078e+08  8.322387e+07    722.0      2715.0
#                  DLX       5.407618e+08  2.295460e+08   3573.0    319963.0
#      22          BFS       3.136109e+08  1.343939e+08   1000.0      2911.0
#                  CP        2.889014e+08  1.238043e+08    819.0      3615.0
#                  DLX       5.528554e+08  2.348113e+08   3593.0    320297.0
# 256  23          BFS       3.994247e+08  1.711632e+08   1852.0      5294.0
#                  CP        3.884431e+08  1.664547e+08   1811.0      7488.0
#                  DLX       1.766309e+09  7.166887e+08  12755.0   4909363.0
#      39          BFS       7.720594e+08  3.308487e+08   2469.0     10014.0
#                  CP        1.035542e+09  4.437596e+08   2505.0     17231.0
#                  DLX       1.795406e+09  7.303962e+08  12839.0   4910935.0
#      54          BFS       1.881017e+09  8.060759e+08   4255.0     22309.0
#                  CP        1.617449e+09  6.931280e+08   3085.0     25960.0
#                  DLX       1.822690e+09  7.432485e+08  12933.0   4912773.0
# 625  46          BFS       1.605919e+09  6.881728e+08   5289.0     23564.0
#                  CP        1.297088e+09  5.558232e+08   4585.0     29039.0
#                  DLX       5.237685e+09  1.869326e+09  36532.0  43124906.0
#      80          BFS       2.565392e+09  1.099319e+09   6832.0     43260.0
#                  CP        2.462314e+09  1.055156e+09   5741.0     52135.0
#                  DLX       5.276632e+09  1.896055e+09  36642.0  43126658.0
#      114         BFS       3.868759e+09  1.657821e+09   8910.0     74036.0
#                  CP        4.074284e+09  1.745931e+09   7361.0     84744.0
#                  DLX       5.315604e+09  1.922791e+09  36784.0  43129146.0
#
#                            Field store  avg inst/method  Regular load  \
# Area Missing ele Strategy
# 81   9           BFS              23.0         168643.0  1.569654e+07
#                  CP               23.0         155560.0  1.393076e+07
#                  DLX           10301.0         148422.0  7.800786e+07
#      16          BFS              23.0         259273.0  3.217381e+07
#                  CP               23.0         265423.0  2.775835e+07
#                  DLX           10504.0         151362.0  7.993108e+07
#      22          BFS              23.0         310468.0  4.482686e+07
#                  CP               23.0         350913.0  4.129109e+07
#                  DLX           10677.0         153857.0  8.157986e+07
# 256  23          BFS              23.0         214600.0  5.710279e+07
#                  CP               23.0         214029.0  5.552846e+07
#                  DLX           32617.0         138480.0  3.006900e+08
#      39          BFS              23.0         310756.0  1.103715e+08
#                  CP               23.0         392333.0  1.480149e+08
#                  DLX           33416.0         139840.0  3.036668e+08
#      54          BFS              23.0         435771.0  2.688902e+08
#                  CP               23.0         496532.0  2.311835e+08
#                  DLX           34340.0         140937.0  3.064605e+08
# 625  46          BFS              23.0         303634.0  2.295936e+08
#                  CP               23.0         282898.0  1.854243e+08
#                  DLX           79252.0         143373.0  1.197935e+09
#      80          BFS              23.0         375497.0  3.667863e+08
#                  CP               23.0         428900.0  3.519770e+08
#                  DLX           80145.0         144005.0  1.193974e+09
#      114         BFS              23.0         434204.0  5.531679e+08
#                  CP               23.0         553496.0  5.823873e+08
#                  DLX           81414.0         144509.0  1.190030e+09
#
#                            Regular store     new  newarray
# Area Missing ele Strategy
# 81   9           BFS          15682315.0    38.0       0.0
#                  CP           13918208.0    85.0       0.0
#                  DLX          74727400.0  1019.0      73.0
#      16          BFS          32148369.0    38.0       0.0
#                  CP           27737885.0   132.0       0.0
#                  DLX          76749867.0  1037.0      66.0
#      22          BFS          44791957.0    38.0       0.0
#                  CP           41263518.0   178.0       0.0
#                  DLX          78483404.0  1051.0      60.0
# 256  23          BFS          57043908.0    45.0       0.0
#                  CP           55476070.0   234.0       0.0
#                  DLX         243647776.0  3149.0     234.0
#      39          BFS         110264456.0    45.0       0.0
#                  CP          147901181.0   548.0       0.0
#                  DLX         247893341.0  3217.0     218.0
#      54          BFS         268651690.0    45.0       0.0
#                  CP          231015122.0   831.0       0.0
#                  DLX         251873715.0  3296.0     203.0
# 625  46          BFS         229349622.0    54.0       0.0
#                  CP          185245263.0   684.0       0.0
#                  DLX         668213063.0  7598.0     580.0
#      80          BFS         366370389.0    54.0       0.0
#                  CP          351668968.0  1250.0       0.0
#                  DLX         674489216.0  7674.0     546.0
#      114         BFS         552495283.0    54.0       0.0
#                  CP          581898322.0  2033.0       0.0
#                  DLX         680765699.0  7782.0     512.0

# %% [markdown]
# ## Notes:
#
# __1)__ __Solving algorithm DLX__ leads to a __high number of instructions and regular store__, excepting to the 16x16 puzzle. Also, it has the __higher new__ value overall.
#
# __2)__ __CP and BFS have similar metrics regarding instructions__. Since the number of instructions will have a high influence in execution time, __they will have similar time executions__.
#
# __3)__ __BFS__ has a much __smaller new__ value.

# %% [markdown]
# # 6. Final conclusions
#
# ## Chosen metrics:
#
# ### 1) Methods (far less overhead than instruction)

# %% [markdown]
# # 7. Auxiliar functions

# %%
def getRatios1(methods, instructions, cost):
    methods_ratio = []
    instructions_ratio = []
    cost_ratio =[]
    counter = 0
    i=0
    while(i<24):
        if counter == 6:
            counter = 0
            methods_ratio.append(None)
            methods_ratio.append(None)
            methods_ratio.append(None)
            instructions_ratio.append(None)
            instructions_ratio.append(None)
            instructions_ratio.append(None)
            cost_ratio.append(None)
            cost_ratio.append(None)
            cost_ratio.append(None)
            i += 3
            continue
        else:
            methods_ratio.append(round(methods[i]/methods[i+3],2))
            instructions_ratio.append(round(instructions[i]/instructions[i+3],2))
            cost_ratio.append(round(cost[i]/cost[i+3],2))
            counter += 1
            i+=1
    
    methods_ratio.append(None)
    methods_ratio.append(None)
    methods_ratio.append(None)
    instructions_ratio.append(None)
    instructions_ratio.append(None)
    instructions_ratio.append(None)
    cost_ratio.append(None)
    cost_ratio.append(None)
    cost_ratio.append(None)
    return methods_ratio, instructions_ratio, cost_ratio

def getRatios2(methods, instructions, cost):
    methods_ratio = []
    instructions_ratio = []
    cost_ratio = []
    i=0
    while(i<27):
        if ((i==0) or (i==9) or (i==18)):
            methods_ratio.append(None)
            methods_ratio.append(None)
            methods_ratio.append(None)
            instructions_ratio.append(None)
            instructions_ratio.append(None)
            instructions_ratio.append(None)
            cost_ratio.append(None)
            cost_ratio.append(None)
            cost_ratio.append(None)
            i += 3
            continue
        else:
            methods_ratio.append(round(methods[i]/methods[i-3],3))
            instructions_ratio.append(round(instructions[i]/instructions[i-3],3))
            cost_ratio.append(round(cost[i]/cost[i-3],3))
            i+=1
    
    return methods_ratio, instructions_ratio, cost_ratio

getRatios3(instructions):
    instructions_ratio = []
    i = 0
    counter = 0
    while(i<27):
        if counter == 2:
            counter = 0
            instructions_ratio.append(None)
        elif counter == 1:
            instructions_ratio.append(round(instructions[i]/instructions[i+2],2))
        else:
            instructions_ratio.append(round(instructions[i]/instructions))

# %%
# Cost of DLX is equals to methods
measurements.loc[measurements['Strategy'] == 'DLX','Cost'] = measurements.loc[measurements['Strategy'] == 'DLX','Methods']
 
# Cost of BFS is 2*(methods + methods * %miss elements *2) = 10000 -> 12000
BFS_methods = measurements.loc[measurements['Strategy']=='BFS','Methods'].values
BFS_miss_el = measurements.loc[measurements['Strategy']=='BFS','% miss elements'].values
measurements.loc[measurements['Strategy'] == 'BFS','Cost'] = 2*(BFS_methods + BFS_methods*BFS_miss_el*2)

# Cost of CP is 2.3*(methods + methods * %miss elements *2)
CP_methods = measurements.loc[measurements['Strategy']=='CP','Methods'].values
CP_miss_el = measurements.loc[measurements['Strategy']=='CP','% miss elements'].values
measurements.loc[measurements['Strategy'] == 'CP','Cost'] = 2.3*(CP_methods + CP_methods*CP_miss_el*2)
